# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
! pip install openpyxl

# %%
flights=pd.read_excel("C:\\Users\\adhil\\OneDrive\\Desktop\\seabornworks\\Flights\\Data_Train.xlsx")

# %%
flights.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
flights["day"]=flights["Date_of_Journey"].str.split("/").str[0]
flights["month"]=flights["Date_of_Journey"].str.split("/").str[1]
flights["year"]=flights["Date_of_Journey"].str.split("/").str[2]

# %%
flights.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price day  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897  24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662   1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882   9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218  12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302  01
#
#   month  year
# 0    03  2019
# 1    05  2019
# 2    06  2019
# ...

# %%
flights.drop(columns="Date_of_Journey",inplace=True)

# %%
flights.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Route', 'Dep_Time', 'Arrival_Time',
#        'Duration', 'Total_Stops', 'Additional_Info', 'Price', 'day', 'month',
#        'year'],
#       dtype='object')

# %%
flights["day"]=flights["day"].astype("int")

# %%
flights["month"]=flights["month"].astype("int")

# %%
flights["year"]=flights["year"].astype("int")

# %%
flights["dep_hr"]=flights["Dep_Time"].str.split(":").str[0]
flights["dep_minute"]=flights["Dep_Time"].str.split(":").str[1]

# %%
flights.drop(columns=("Dep_Time"),inplace=True)

# %%
flights["Arrival_Time"] = flights["Arrival_Time"].str.split(" ").str[0]
flights["arrival_hr"] = flights["Arrival_Time"].str.split(":").str[0]
flights["arrival_minute"] = flights["Arrival_Time"].str.split(":").str[1]
flights.drop(columns="Arrival_Time", inplace=True)

# %%
flights.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info  Price  day  month  year dep_hr dep_minute  \
# 0    non-stop         No info   3897   24      3  2019     22         20
# 1     2 stops         No info   7662    1      5  2019     05         50
# 2     2 stops         No info  13882    9      6  2019     09         25
# 3      1 stop         No info   6218   12      5  2019     18         05
# 4      1 stop         No info  13302    1      3  2019     16         50
#
#   arrival_hr arrival_minute
# 0         01             10
# 1         13             15
# ...

# %%
flights["Total_Stops"].value_counts()
# Out:
# Total_Stops
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: count, dtype: int64

# %%
flights["Total_Stops"]=flights["Total_Stops"].map({"non-stop":0,"1 stop":1,"2 stops":2,"3 stops":3,"4 stops":4,np.nan:1})

# %%
flights["Total_Stops"]
# Out:
# 0        0
# 1        2
# 2        2
# 3        1
# 4        1
#         ..
# 10678    0
# 10679    0
# 10680    0
# 10681    0
# 10682    2
# Name: Total_Stops, Length: 10683, dtype: int64

# %%
flights[flights["Total_Stops"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Airline, Source, Destination, Route, Duration, Total_Stops, Additional_Info, Price, day, month, year, dep_hr, dep_minute, arrival_hr, arrival_minute]
# Index: []
